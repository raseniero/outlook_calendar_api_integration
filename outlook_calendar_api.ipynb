# %% [markdown]
# ### Install Modules

# %% [markdown]
# Install all dependencies inside requirements.txt and other dependencies

# %%
# !python -m pip install -r requirements.txt

# Install the Azure Identity library
# !python -m pip install azure-identity

# Install Dotenv for environment variable management
# !python -m pip install python-dotenv

# Install nest_asyncio to allow nested event loops in Jupyter
# !python -m pip install nest_asyncio

# Install pytz for timezone handling
# !python -m pip install pytz
# Out:
# Collecting aiohappyeyeballs==2.6.1 (from -r requirements.txt (line 1))
#   Obtaining dependency information for aiohappyeyeballs==2.6.1 from https://files.pythonhosted.org/packages/0f/15/5bf3b99495fb160b63f95972b81750f18f7f4e02ad051373b669d17d44f2/aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiohttp==3.11.18 (from -r requirements.txt (line 2))
#   Obtaining dependency information for aiohttp==3.11.18 from https://files.pythonhosted.org/packages/33/9a/e34e65506e06427b111e19218a99abf627638a9703f4b8bcc3e3021277ed/aiohttp-3.11.18-cp312-cp312-win_amd64.whl.metadata
#   Downloading aiohttp-3.11.18-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Collecting aiosignal==1.3.2 (from -r requirements.txt (line 3))
#   Obtaining dependency information for aiosignal==1.3.2 from https://files.pythonhosted.org/packages/ec/6a/bc7e17a3e87a2985d3e8f4da4cd0f481060eb78fb08596c42be62c90a4d9/aiosignal-1.3.2-py2.py3-none-any.whl.metadata
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting anyio==4.9.0 (from -r requirements.txt (line 4))
#   Obtaining dependency information for anyio==4.9.0 from https://files.pythonhosted.org/packages/a1/ee/48ca1a7c89ffec8b6a0c5d02b89c305671d5ffd8d3c94acf8b8c408575bb/anyio-4.9.0-py3-none-any.whl.metadata
#   Downloading anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting appnope==0.1.4 (from -r requirements.txt (line 5))
#   Obtaining dependency information for appnope==0.1.4 from https://files.pythonhosted.org/packages/81/29/5ecc3a15d5a33e31b26c11426c45c501e439cb865d0bff96315d86443b78/appnope-0.1.4-py2.py3-none-any.whl.metadata
#   Downloading appnope-0.1.4-py2.py3-none-any.whl.metadata (908 bytes)
# Requirement already satisfied: asttokens==3.0.0 in .\.venv\lib\site-packages (from -r requirements.txt (line 6)) (3.0.0)
# Collecting attrs==25.3.0 (from -r requirements.txt (line 7))
#   Obtaining dependency information for attrs==25.3.0 from https://files.pythonhosted.org/packages/77/06/bb80f5f86020c4551da315d78b3ab75e8228f89f0162f2c3a819e407941a/attrs-25.3.0-py3-none-any.whl.metadata
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting azure-core==1.33.0 (from -r requirements.txt (line 8))
#   Obtaining dependency information for azure-core==1.33.0 from https://files.pythonhosted.org/packages/07/b7/76b7e144aa53bd206bf1ce34fa75350472c3f69bf30e5c8c18bc9881035d/azure_core-1.33.0-py3-none-any.whl.metadata
#   Downloading azure_core-1.33.0-py3-none-any.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.6 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/42.6 kB ? eta -:--:--
#      --------------------------- ---------- 30.7/42.6 kB 660.6 kB/s eta 0:00:01
#      --------------------------- ---------- 30.7/42.6 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 42.6/42.6 kB 231.2 kB/s eta 0:00:00
# Collecting azure-identity==1.21.0 (from -r requirements.txt (line 9))
#   Obtaining dependency information for azure-identity==1.21.0 from https://files.pythonhosted.org/packages/3d/9f/1f9f3ef4f49729ee207a712a5971a9ca747f2ca47d9cbf13cf6953e3478a/azure_identity-1.21.0-py3-none-any.whl.metadata
#   Downloading azure_identity-1.21.0-py3-none-any.whl.metadata (81 kB)
#      ---------------------------------------- 0.0/81.3 kB ? eta -:--:--
#      --------------- ------------------------ 30.7/81.3 kB 1.3 MB/s eta 0:00:01
#      --------------------------------- ---- 71.7/81.3 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 81.3/81.3 kB 911.4 kB/s eta 0:00:00
# Collecting certifi==2025.4.26 (from -r requirements.txt (line 10))
#   Obtaining dependency information for certifi==2025.4.26 from https://files.pythonhosted.org/packages/4a/7e/3db2bd1b1f9e95f7cddca6d6e75e2f2bd9f51b1246e546d88addca0106bd/certifi-2025.4.26-py3-none-any.whl.metadata
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Collecting cffi==1.17.1 (from -r requirements.txt (line 11))
#   Obtaining dependency information for cffi==1.17.1 from https://files.pythonhosted.org/packages/50/b9/db34c4755a7bd1cb2d1603ac3863f22bcecbd1ba29e5ee841a4bc510b294/cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata (1.6 kB)
# Collecting charset-normalizer==3.4.1 (from -r requirements.txt (line 12))
#   Obtaining dependency information for charset-normalizer==3.4.1 from https://files.pythonhosted.org/packages/21/5b/1b390b03b1d16c7e382b561c5329f83cc06623916aab983e8ab9239c7d5c/charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Requirement already satisfied: comm==0.2.2 in .\.venv\lib\site-packages (from -r requirements.txt (line 13)) (0.2.2)
# Collecting cryptography==44.0.2 (from -r requirements.txt (line 14))
#   Obtaining dependency information for cryptography==44.0.2 from https://files.pythonhosted.org/packages/33/cf/1f7649b8b9a3543e042d3f348e398a061923ac05b507f3f4d95f11938aa9/cryptography-44.0.2-cp39-abi3-win_amd64.whl.metadata
#   Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: debugpy==1.8.14 in .\.venv\lib\site-packages (from -r requirements.txt (line 15)) (1.8.14)
# Requirement already satisfied: decorator==5.2.1 in .\.venv\lib\site-packages (from -r requirements.txt (line 16)) (5.2.1)
# Collecting Deprecated==1.2.18 (from -r requirements.txt (line 17))
#   Obtaining dependency information for Deprecated==1.2.18 from https://files.pythonhosted.org/packages/6e/c6/ac0b6c1e2d138f1002bcf799d330bd6d85084fece321e662a14223794041/Deprecated-1.2.18-py2.py3-none-any.whl.metadata
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: executing==2.2.0 in .\.venv\lib\site-packages (from -r requirements.txt (line 18)) (2.2.0)
# Collecting frozenlist==1.6.0 (from -r requirements.txt (line 19))
#   Obtaining dependency information for frozenlist==1.6.0 from https://files.pythonhosted.org/packages/80/2e/fb4ed62a65f8cd66044706b1013f0010930d8cbb0729a2219561ea075434/frozenlist-1.6.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting h11==0.16.0 (from -r requirements.txt (line 20))
#   Obtaining dependency information for h11==0.16.0 from https://files.pythonhosted.org/packages/04/4b/29cac41a4d98d144bf5f6d33995617b185d14b22401f75ca86f384e87ff1/h11-0.16.0-py3-none-any.whl.metadata
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting h2==4.2.0 (from -r requirements.txt (line 21))
#   Obtaining dependency information for h2==4.2.0 from https://files.pythonhosted.org/packages/d0/9e/984486f2d0a0bd2b024bf4bc1c62688fcafa9e61991f041fb0e2def4a982/h2-4.2.0-py3-none-any.whl.metadata
#   Downloading h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hpack==4.1.0 (from -r requirements.txt (line 22))
#   Obtaining dependency information for hpack==4.1.0 from https://files.pythonhosted.org/packages/07/c6/80c95b1b2b94682a72cbdbfb85b81ae2daffa4291fbfa1b1464502ede10d/hpack-4.1.0-py3-none-any.whl.metadata
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting httpcore==1.0.9 (from -r requirements.txt (line 23))
#   Obtaining dependency information for httpcore==1.0.9 from https://files.pythonhosted.org/packages/7e/f5/f66802a942d491edb555dd61e3a9961140fd64c90bce1eafd741609d334d/httpcore-1.0.9-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting httpx==0.28.1 (from -r requirements.txt (line 24))
#   Obtaining dependency information for httpx==0.28.1 from https://files.pythonhosted.org/packages/2a/39/e50c7c3a983047577ee07d2a9e53faf5a69493943ec3f6a384bdc792deb2/httpx-0.28.1-py3-none-any.whl.metadata
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting hyperframe==6.1.0 (from -r requirements.txt (line 25))
#   Obtaining dependency information for hyperframe==6.1.0 from https://files.pythonhosted.org/packages/48/30/47d0bf6072f7252e6521f3447ccfa40b421b6824517f82854703d0f5a98b/hyperframe-6.1.0-py3-none-any.whl.metadata
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting idna==3.10 (from -r requirements.txt (line 26))
#   Obtaining dependency information for idna==3.10 from https://files.pythonhosted.org/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl.metadata
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting importlib_metadata==8.6.1 (from -r requirements.txt (line 27))
#   Obtaining dependency information for importlib_metadata==8.6.1 from https://files.pythonhosted.org/packages/79/9d/0fb148dc4d6fa4a7dd1d8378168d9b4cd8d4560a6fbf6f0121c5fc34eb68/importlib_metadata-8.6.1-py3-none-any.whl.metadata
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: ipykernel==6.29.5 in .\.venv\lib\site-packages (from -r requirements.txt (line 28)) (6.29.5)
# Collecting ipython==9.2.0 (from -r requirements.txt (line 29))
#   Obtaining dependency information for ipython==9.2.0 from https://files.pythonhosted.org/packages/78/ce/5e897ee51b7d26ab4e47e5105e7368d40ce6cfae2367acdf3165396d50be/ipython-9.2.0-py3-none-any.whl.metadata
#   Downloading ipython-9.2.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in .\.venv\lib\site-packages (from -r requirements.txt (line 30)) (1.1.1)
# Requirement already satisfied: jedi==0.19.2 in .\.venv\lib\site-packages (from -r requirements.txt (line 31)) (0.19.2)
# Requirement already satisfied: jupyter_client==8.6.3 in .\.venv\lib\site-packages (from -r requirements.txt (line 32)) (8.6.3)
# Collecting jupyter_core==5.7.2 (from -r requirements.txt (line 33))
#   Obtaining dependency information for jupyter_core==5.7.2 from https://files.pythonhosted.org/packages/c9/fb/108ecd1fe961941959ad0ee4e12ee7b8b1477247f30b1fdfd83ceaf017f0/jupyter_core-5.7.2-py3-none-any.whl.metadata
#   Downloading jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in .\.venv\lib\site-packages (from -r requirements.txt (line 34)) (0.1.7)
# Collecting microsoft-kiota-abstractions==1.9.3 (from -r requirements.txt (line 35))
#   Obtaining dependency information for microsoft-kiota-abstractions==1.9.3 from https://files.pythonhosted.org/packages/b4/75/4bac7a34741c59298cdb9944f8588fbdef0ab66150e847cb459c73cab221/microsoft_kiota_abstractions-1.9.3-py3-none-any.whl.metadata
#   Downloading microsoft_kiota_abstractions-1.9.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting microsoft-kiota-authentication-azure==1.9.3 (from -r requirements.txt (line 36))
#   Obtaining dependency information for microsoft-kiota-authentication-azure==1.9.3 from https://files.pythonhosted.org/packages/d1/38/89420a0f5417a1bf5603de2e74a8981da79fcf1da456c0be9f7cff9c2864/microsoft_kiota_authentication_azure-1.9.3-py3-none-any.whl.metadata
#   Downloading microsoft_kiota_authentication_azure-1.9.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting microsoft-kiota-http==1.9.3 (from -r requirements.txt (line 37))
#   Obtaining dependency information for microsoft-kiota-http==1.9.3 from https://files.pythonhosted.org/packages/cf/f4/ef67b7e6dea7d77930df41f4a5926bbba2e362c28a46615908f2d00cf146/microsoft_kiota_http-1.9.3-py3-none-any.whl.metadata
#   Downloading microsoft_kiota_http-1.9.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting microsoft-kiota-serialization-form==1.9.3 (from -r requirements.txt (line 38))
#   Obtaining dependency information for microsoft-kiota-serialization-form==1.9.3 from https://files.pythonhosted.org/packages/4a/f6/e82c66495173b9a1da770e6cc2ad12f953baf7f70038befcb5be67ef15ab/microsoft_kiota_serialization_form-1.9.3-py3-none-any.whl.metadata
#   Downloading microsoft_kiota_serialization_form-1.9.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting microsoft-kiota-serialization-json==1.9.3 (from -r requirements.txt (line 39))
#   Obtaining dependency information for microsoft-kiota-serialization-json==1.9.3 from https://files.pythonhosted.org/packages/b0/f0/ba6180884d425ab1174f6bd00af76b38466bc767d1853586e9116962227a/microsoft_kiota_serialization_json-1.9.3-py3-none-any.whl.metadata
#   Downloading microsoft_kiota_serialization_json-1.9.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting microsoft-kiota-serialization-multipart==1.9.3 (from -r requirements.txt (line 40))
#   Obtaining dependency information for microsoft-kiota-serialization-multipart==1.9.3 from https://files.pythonhosted.org/packages/7d/a3/1a4ddf488c58c8d4f6f88e015a55424692da4973395073d554282173b952/microsoft_kiota_serialization_multipart-1.9.3-py3-none-any.whl.metadata
#   Downloading microsoft_kiota_serialization_multipart-1.9.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting microsoft-kiota-serialization-text==1.9.3 (from -r requirements.txt (line 41))
#   Obtaining dependency information for microsoft-kiota-serialization-text==1.9.3 from https://files.pythonhosted.org/packages/6f/71/9f9f0e8943c225695624db7875be27d9aa45bdd0e2d84ff98005a2ff4148/microsoft_kiota_serialization_text-1.9.3-py3-none-any.whl.metadata
#   Downloading microsoft_kiota_serialization_text-1.9.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting msal==1.32.3 (from -r requirements.txt (line 42))
#   Obtaining dependency information for msal==1.32.3 from https://files.pythonhosted.org/packages/04/bf/81516b9aac7fd867709984d08eb4db1d2e3fe1df795c8e442cde9b568962/msal-1.32.3-py3-none-any.whl.metadata
#   Downloading msal-1.32.3-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions==1.3.1 (from -r requirements.txt (line 43))
#   Obtaining dependency information for msal-extensions==1.3.1 from https://files.pythonhosted.org/packages/5e/75/bd9b7bb966668920f06b200e84454c8f3566b102183bc55c5473d96cb2b9/msal_extensions-1.3.1-py3-none-any.whl.metadata
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting msgraph-core==1.3.3 (from -r requirements.txt (line 44))
#   Obtaining dependency information for msgraph-core==1.3.3 from https://files.pythonhosted.org/packages/3c/9a/506335cbad42698b2c05e1da0b3e4c19f9cd04d379abc9758e822115ab12/msgraph_core-1.3.3-py3-none-any.whl.metadata
#   Downloading msgraph_core-1.3.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting msgraph-sdk==1.28.0 (from -r requirements.txt (line 45))
#   Obtaining dependency information for msgraph-sdk==1.28.0 from https://files.pythonhosted.org/packages/a8/58/d8e9593ea81779d503831b5b06c8d9881d5affefe3df99ca20112c969e6f/msgraph_sdk-1.28.0-py3-none-any.whl.metadata
#   Downloading msgraph_sdk-1.28.0-py3-none-any.whl.metadata (13 kB)
# Collecting multidict==6.4.3 (from -r requirements.txt (line 46))
#   Obtaining dependency information for multidict==6.4.3 from https://files.pythonhosted.org/packages/06/24/c8fdff4f924d37225dc0c56a28b1dca10728fc2233065fafeb27b4b125be/multidict-6.4.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio==1.6.0 in .\.venv\lib\site-packages (from -r requirements.txt (line 47)) (1.6.0)
# Collecting opentelemetry-api==1.32.1 (from -r requirements.txt (line 48))
#   Obtaining dependency information for opentelemetry-api==1.32.1 from https://files.pythonhosted.org/packages/12/f2/89ea3361a305466bc6460a532188830351220b5f0851a5fa133155c16eca/opentelemetry_api-1.32.1-py3-none-any.whl.metadata
#   Downloading opentelemetry_api-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-sdk==1.32.1 (from -r requirements.txt (line 49))
#   Obtaining dependency information for opentelemetry-sdk==1.32.1 from https://files.pythonhosted.org/packages/dc/00/d3976cdcb98027aaf16f1e980e54935eb820872792f0eaedd4fd7abb5964/opentelemetry_sdk-1.32.1-py3-none-any.whl.metadata
#   Downloading opentelemetry_sdk-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-semantic-conventions==0.53b1 (from -r requirements.txt (line 50))
#   Obtaining dependency information for opentelemetry-semantic-conventions==0.53b1 from https://files.pythonhosted.org/packages/27/6b/a8fb94760ef8da5ec283e488eb43235eac3ae7514385a51b6accf881e671/opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl.metadata
#   Downloading opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging==25.0 in .\.venv\lib\site-packages (from -r requirements.txt (line 51)) (25.0)
# Requirement already satisfied: parso==0.8.4 in .\.venv\lib\site-packages (from -r requirements.txt (line 52)) (0.8.4)
# Collecting pexpect==4.9.0 (from -r requirements.txt (line 53))
#   Obtaining dependency information for pexpect==4.9.0 from https://files.pythonhosted.org/packages/9e/c3/059298687310d527a58bb01f3b1965787ee3b40dce76752eda8b44e9a2c5/pexpect-4.9.0-py2.py3-none-any.whl.metadata
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting platformdirs==4.3.7 (from -r requirements.txt (line 54))
#   Obtaining dependency information for platformdirs==4.3.7 from https://files.pythonhosted.org/packages/6d/45/59578566b3275b8fd9157885918fcd0c4d74162928a5310926887b856a51/platformdirs-4.3.7-py3-none-any.whl.metadata
#   Downloading platformdirs-4.3.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: prompt_toolkit==3.0.51 in .\.venv\lib\site-packages (from -r requirements.txt (line 55)) (3.0.51)
# Collecting propcache==0.3.1 (from -r requirements.txt (line 56))
#   Obtaining dependency information for propcache==0.3.1 from https://files.pythonhosted.org/packages/24/bb/3b1b01da5dd04c77a204c84e538ff11f624e31431cfde7201d9110b092b1/propcache-0.3.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: psutil==7.0.0 in .\.venv\lib\site-packages (from -r requirements.txt (line 57)) (7.0.0)
# Collecting ptyprocess==0.7.0 (from -r requirements.txt (line 58))
#   Obtaining dependency information for ptyprocess==0.7.0 from https://files.pythonhosted.org/packages/22/a6/858897256d0deac81a172289110f31629fc4cee19b6f01283303e18c8db3/ptyprocess-0.7.0-py2.py3-none-any.whl.metadata
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pure_eval==0.2.3 in .\.venv\lib\site-packages (from -r requirements.txt (line 59)) (0.2.3)
# Collecting pycparser==2.22 (from -r requirements.txt (line 60))
#   Obtaining dependency information for pycparser==2.22 from https://files.pythonhosted.org/packages/13/a3/a812df4e2dd5696d1f351d58b8fe16a405b234ad2886a0dab9183fb78109/pycparser-2.22-py3-none-any.whl.metadata
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: Pygments==2.19.1 in .\.venv\lib\site-packages (from -r requirements.txt (line 61)) (2.19.1)
# Collecting PyJWT==2.10.1 (from -r requirements.txt (line 62))
#   Obtaining dependency information for PyJWT==2.10.1 from https://files.pythonhosted.org/packages/61/ad/689f02752eeec26aed679477e80e632ef1b682313be70793d798c1d5fc8f/PyJWT-2.10.1-py3-none-any.whl.metadata
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in .\.venv\lib\site-packages (from -r requirements.txt (line 63)) (2.9.0.post0)
# Collecting python-dotenv==1.1.0 (from -r requirements.txt (line 64))
#   Obtaining dependency information for python-dotenv==1.1.0 from https://files.pythonhosted.org/packages/1e/18/98a99ad95133c6a6e2005fe89faedf294a748bd5dc803008059409ac9b1e/python_dotenv-1.1.0-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pyzmq==26.4.0 in .\.venv\lib\site-packages (from -r requirements.txt (line 65)) (26.4.0)
# Collecting requests==2.32.3 (from -r requirements.txt (line 66))
#   Obtaining dependency information for requests==2.32.3 from https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl.metadata
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six==1.17.0 in .\.venv\lib\site-packages (from -r requirements.txt (line 67)) (1.17.0)
# Collecting sniffio==1.3.1 (from -r requirements.txt (line 68))
#   Obtaining dependency information for sniffio==1.3.1 from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: stack-data==0.6.3 in .\.venv\lib\site-packages (from -r requirements.txt (line 69)) (0.6.3)
# Collecting std-uritemplate==2.0.3 (from -r requirements.txt (line 70))
#   Obtaining dependency information for std-uritemplate==2.0.3 from https://files.pythonhosted.org/packages/d3/18/43e8185dd1545b9cd019a2e3f4bfb6df29ebcbe4b7c5273d647226bc0616/std_uritemplate-2.0.3-py3-none-any.whl.metadata
#   Downloading std_uritemplate-2.0.3-py3-none-any.whl.metadata (8.6 kB)
# Collecting tornado==6.4.2 (from -r requirements.txt (line 71))
#   Obtaining dependency information for tornado==6.4.2 from https://files.pythonhosted.org/packages/61/cc/58b1adeb1bb46228442081e746fcdbc4540905c87e8add7c277540934edb/tornado-6.4.2-cp38-abi3-win_amd64.whl.metadata
#   Downloading tornado-6.4.2-cp38-abi3-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: traitlets==5.14.3 in .\.venv\lib\site-packages (from -r requirements.txt (line 72)) (5.14.3)
# Collecting typing_extensions==4.13.2 (from -r requirements.txt (line 73))
#   Obtaining dependency information for typing_extensions==4.13.2 from https://files.pythonhosted.org/packages/8b/54/b1ae86c0973cc6f0210b53d508ca3641fb6d0c56823f288d108bc7ab3cc8/typing_extensions-4.13.2-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting urllib3==2.4.0 (from -r requirements.txt (line 74))
#   Obtaining dependency information for urllib3==2.4.0 from https://files.pythonhosted.org/packages/6b/11/cc635220681e93a0183390e26485430ca2c7b5f9d33b15c74c2861cb8091/urllib3-2.4.0-py3-none-any.whl.metadata
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wcwidth==0.2.13 in .\.venv\lib\site-packages (from -r requirements.txt (line 75)) (0.2.13)
# Collecting wrapt==1.17.2 (from -r requirements.txt (line 76))
#   Obtaining dependency information for wrapt==1.17.2 from https://files.pythonhosted.org/packages/15/06/1dbf478ea45c03e78a6a8c4be4fdc3c3bddea5c8de8a93bc971415e47f0f/wrapt-1.17.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading wrapt-1.17.2-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Collecting yarl==1.20.0 (from -r requirements.txt (line 77))
#   Obtaining dependency information for yarl==1.20.0 from https://files.pythonhosted.org/packages/ca/c6/333fe0338305c0ac1c16d5aa7cc4841208d3252bbe62172e0051006b5445/yarl-1.20.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl.metadata (74 kB)
#      ---------------------------------------- 0.0/74.8 kB ? eta -:--:--
#      -------------------------------------- - 71.7/74.8 kB 2.0 MB/s eta 0:00:01
#      ---------------------------------------- 74.8/74.8 kB 1.4 MB/s eta 0:00:00
# Collecting zipp==3.21.0 (from -r requirements.txt (line 78))
#   Obtaining dependency information for zipp==3.21.0 from https://files.pythonhosted.org/packages/b7/1a/7e4798e9339adc931158c9d69ecc34f5e6791489d469f5e50ec15e35f458/zipp-3.21.0-py3-none-any.whl.metadata
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting tabulate==0.9.0 (from -r requirements.txt (line 79))
#   Obtaining dependency information for tabulate==0.9.0 from https://files.pythonhosted.org/packages/40/44/4a5f08c96eb108af5cb50b41f76142f0afa346dfa99d5296fe7202a11854/tabulate-0.9.0-py3-none-any.whl.metadata
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting beautifulsoup4==4.13.4 (from -r requirements.txt (line 80))
#   Obtaining dependency information for beautifulsoup4==4.13.4 from https://files.pythonhosted.org/packages/50/cd/30110dc0ffcf3b131156077b90e9f60ed75711223f306da4db08eff8403b/beautifulsoup4-4.13.4-py3-none-any.whl.metadata
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: colorama in .\.venv\lib\site-packages (from ipython==9.2.0->-r requirements.txt (line 29)) (0.4.6)
# Requirement already satisfied: pywin32>=300 in .\.venv\lib\site-packages (from jupyter_core==5.7.2->-r requirements.txt (line 33)) (310)
# Collecting soupsieve>1.2 (from beautifulsoup4==4.13.4->-r requirements.txt (line 80))
#   Obtaining dependency information for soupsieve>1.2 from https://files.pythonhosted.org/packages/e7/9c/0e6afc12c269578be5c0c1c9f4b49a8d32770a080260c333ac04cc1c832d/soupsieve-2.7-py3-none-any.whl.metadata
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiohttp-3.11.18-cp312-cp312-win_amd64.whl (439 kB)
#    ---------------------------------------- 0.0/439.4 kB ? eta -:--:--
#    --------- ------------------------------ 102.4/439.4 kB 2.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 122.9/439.4 kB 2.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 122.9/439.4 kB 2.4 MB/s eta 0:00:01
#    --------------- ---------------------- 174.1/439.4 kB 876.1 kB/s eta 0:00:01
#    ---------------------------- ----------- 317.4/439.4 kB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 389.1/439.4 kB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 389.1/439.4 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 439.4/439.4 kB 1.2 MB/s eta 0:00:00
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#    ---------------------------------------- 0.0/100.9 kB ? eta -:--:--
#    ---------------------------------------- 100.9/100.9 kB 6.0 MB/s eta 0:00:00
# Downloading appnope-0.1.4-py2.py3-none-any.whl (4.3 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.8 kB ? eta -:--:--
#    ---------------------------------------- 63.8/63.8 kB ? eta 0:00:00
# Downloading azure_core-1.33.0-py3-none-any.whl (207 kB)
#    ---------------------------------------- 0.0/207.1 kB ? eta -:--:--
#    ---------------------------------------  204.8/207.1 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 207.1/207.1 kB 6.3 MB/s eta 0:00:00
# Downloading azure_identity-1.21.0-py3-none-any.whl (189 kB)
#    ---------------------------------------- 0.0/189.2 kB ? eta -:--:--
#    ---------------------------------------- 189.2/189.2 kB 5.8 MB/s eta 0:00:00
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
#    ---------------------------------------- 0.0/159.6 kB ? eta -:--:--
#    ---------------------------------------- 159.6/159.6 kB 4.8 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/182.0 kB ? eta -:--:--
#    ---------------------------------------- 182.0/182.0 kB 3.7 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
#    ---------------------------------------- 0.0/102.8 kB ? eta -:--:--
#    ---------------------------------------- 102.8/102.8 kB 6.2 MB/s eta 0:00:00
# Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/3.2 MB 7.3 MB/s eta 0:00:01
#    ------ --------------------------------- 0.5/3.2 MB 6.3 MB/s eta 0:00:01
#    ------ --------------------------------- 0.5/3.2 MB 6.3 MB/s eta 0:00:01
#    ------- -------------------------------- 0.6/3.2 MB 3.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.9/3.2 MB 3.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.4/3.2 MB 5.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.5/3.2 MB 5.8 MB/s eta 0:00:01
#    --------------------- ------------------ 1.7/3.2 MB 4.9 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.2 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------ --- 2.9/3.2 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  3.2/3.2 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 6.4 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl (120 kB)
#    ---------------------------------------- 0.0/120.5 kB ? eta -:--:--
#    ---------------------------------------- 120.5/120.5 kB ? eta 0:00:00
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading h2-4.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#    ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.8 kB ? eta -:--:--
#    ---------------------------------------- 78.8/78.8 kB 4.3 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 4.2 MB/s eta 0:00:00
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.4 kB ? eta -:--:--
#    ---------------------------------------- 70.4/70.4 kB ? eta 0:00:00
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading ipython-9.2.0-py3-none-any.whl (604 kB)
#    ---------------------------------------- 0.0/604.3 kB ? eta -:--:--
#    --------------------------------------- 604.3/604.3 kB 39.6 MB/s eta 0:00:00
# Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Downloading microsoft_kiota_abstractions-1.9.3-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
#    ---------------------------------------- 44.4/44.4 kB 2.3 MB/s eta 0:00:00
# Downloading microsoft_kiota_authentication_azure-1.9.3-py3-none-any.whl (6.9 kB)
# Downloading microsoft_kiota_http-1.9.3-py3-none-any.whl (31 kB)
# Downloading microsoft_kiota_serialization_form-1.9.3-py3-none-any.whl (10 kB)
# Downloading microsoft_kiota_serialization_json-1.9.3-py3-none-any.whl (11 kB)
# Downloading microsoft_kiota_serialization_multipart-1.9.3-py3-none-any.whl (6.6 kB)
# Downloading microsoft_kiota_serialization_text-1.9.3-py3-none-any.whl (8.8 kB)
# Downloading msal-1.32.3-py3-none-any.whl (115 kB)
#    ---------------------------------------- 0.0/115.4 kB ? eta -:--:--
#    ---------------------------------------- 115.4/115.4 kB ? eta 0:00:00
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Downloading msgraph_core-1.3.3-py3-none-any.whl (35 kB)
# Downloading msgraph_sdk-1.28.0-py3-none-any.whl (25.1 MB)
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/25.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/25.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/25.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/25.1 MB ? eta -:--:--
#    - -------------------------------------- 1.0/25.1 MB 4.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.7/25.1 MB 14.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 3.7/25.1 MB 14.0 MB/s eta 0:00:02
#    ------- -------------------------------- 4.5/25.1 MB 12.5 MB/s eta 0:00:02
#    -------- ------------------------------- 5.4/25.1 MB 13.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.3/25.1 MB 13.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.7/25.1 MB 13.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.5/25.1 MB 13.7 MB/s eta 0:00:02
#    ------------- -------------------------- 8.4/25.1 MB 14.1 MB/s eta 0:00:02
#    -------------- ------------------------- 9.3/25.1 MB 14.6 MB/s eta 0:00:02
#    --------------- ------------------------ 9.8/25.1 MB 14.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.6/25.1 MB 18.7 MB/s eta 0:00:01
#    ------------------ --------------------- 11.6/25.1 MB 18.7 MB/s eta 0:00:01
#    ------------------- -------------------- 12.5/25.1 MB 18.2 MB/s eta 0:00:01
#    -------------------- ------------------- 12.9/25.1 MB 16.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 13.8/25.1 MB 15.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 14.8/25.1 MB 16.8 MB/s eta 0:00:01
#    ------------------------ --------------- 15.4/25.1 MB 16.8 MB/s eta 0:00:01
#    ------------------------- -------------- 16.2/25.1 MB 16.8 MB/s eta 0:00:01
#    --------------------------- ------------ 17.1/25.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 18.1/25.1 MB 17.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.7/25.1 MB 17.2 MB/s eta 0:00:01
#    ------------------------------- -------- 19.6/25.1 MB 17.2 MB/s eta 0:00:01
#    -------------------------------- ------- 20.5/25.1 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.4/25.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.0/25.1 MB 17.2 MB/s eta 0:00:01
#    ------------------------------------ --- 22.9/25.1 MB 18.2 MB/s eta 0:00:01
#    ------------------------------------- -- 23.8/25.1 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------  24.5/25.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------- 25.1/25.1 MB 12.6 MB/s eta 0:00:00
# Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl (38 kB)
# Downloading opentelemetry_api-1.32.1-py3-none-any.whl (65 kB)
#    ---------------------------------------- 0.0/65.3 kB ? eta -:--:--
#    ---------------------------------------- 65.3/65.3 kB 3.4 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.32.1-py3-none-any.whl (118 kB)
#    ---------------------------------------- 0.0/119.0 kB ? eta -:--:--
#    ---------------------------------------- 119.0/119.0 kB ? eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl (188 kB)
#    ---------------------------------------- 0.0/188.4 kB ? eta -:--:--
#    ---------------------------------------- 188.4/188.4 kB ? eta 0:00:00
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.8 kB ? eta -:--:--
#    ---------------------------------------- 63.8/63.8 kB 3.6 MB/s eta 0:00:00
# Downloading platformdirs-4.3.7-py3-none-any.whl (18 kB)
# Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl (44 kB)
#    ---------------------------------------- 0.0/44.8 kB ? eta -:--:--
#    ---------------------------------------- 44.8/44.8 kB ? eta 0:00:00
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.6 kB ? eta -:--:--
#    ---------------------------------------- 117.6/117.6 kB ? eta 0:00:00
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB ? eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading std_uritemplate-2.0.3-py3-none-any.whl (6.5 kB)
# Downloading tornado-6.4.2-cp38-abi3-win_amd64.whl (438 kB)
#    ---------------------------------------- 0.0/438.9 kB ? eta -:--:--
#    ---------------------------------------- 438.9/438.9 kB 9.3 MB/s eta 0:00:00
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.8 kB ? eta -:--:--
#    ---------------------------------------- 45.8/45.8 kB ? eta 0:00:00
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.7 kB ? eta -:--:--
#    ---------------------------------------- 128.7/128.7 kB 7.9 MB/s eta 0:00:00
# Downloading wrapt-1.17.2-cp312-cp312-win_amd64.whl (38 kB)
# Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl (92 kB)
#    ---------------------------------------- 0.0/92.9 kB ? eta -:--:--
#    ---------------------------------------- 92.9/92.9 kB ? eta 0:00:00
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#    ---------------------------------------- 0.0/187.3 kB ? eta -:--:--
#    --------------------------------------- 187.3/187.3 kB 11.8 MB/s eta 0:00:00
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Installing collected packages: ptyprocess, zipp, wrapt, urllib3, typing_extensions, tornado, tabulate, std-uritemplate, soupsieve, sniffio, python-dotenv, PyJWT, pycparser, propcache, platformdirs, pexpect, multidict, idna, hyperframe, hpack, h11, frozenlist, charset-normalizer, certifi, attrs, appnope, aiohappyeyeballs, yarl, requests, jupyter_core, ipython, importlib_metadata, httpcore, h2, Deprecated, cffi, beautifulsoup4, anyio, aiosignal, opentelemetry-api, httpx, cryptography, azure-core, aiohttp, opentelemetry-semantic-conventions, opentelemetry-sdk, msal, msal-extensions, microsoft-kiota-abstractions, microsoft-kiota-serialization-text, microsoft-kiota-serialization-multipart, microsoft-kiota-serialization-json, microsoft-kiota-serialization-form, microsoft-kiota-http, microsoft-kiota-authentication-azure, azure-identity, msgraph-core, msgraph-sdk
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.5.1
#     Uninstalling tornado-6.5.1:
#       Successfully uninstalled tornado-6.5.1
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'D:\\outlook_calendar_api_integration\\.venv\\Lib\\site-packages\\~ornado\\speedups.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting azure-identity
#   Obtaining dependency information for azure-identity from https://files.pythonhosted.org/packages/07/16/a51d47780f41e4b87bb2d454df6aea90a44a346e918ac189d3700f3d728d/azure_identity-1.23.0-py3-none-any.whl.metadata
#   Downloading azure_identity-1.23.0-py3-none-any.whl.metadata (81 kB)
#      ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/81.9 kB ? eta -:--:--
#      --------- ---------------------------- 20.5/81.9 kB 131.3 kB/s eta 0:00:01
#      --------- ---------------------------- 20.5/81.9 kB 131.3 kB/s eta 0:00:01
#      -------------- ----------------------- 30.7/81.9 kB 131.3 kB/s eta 0:00:01
#      ------------------- ------------------ 41.0/81.9 kB 151.3 kB/s eta 0:00:01
#      ------------------- ------------------ 41.0/81.9 kB 151.3 kB/s eta 0:00:01
#      ---------------------------- --------- 61.4/81.9 kB 182.2 kB/s eta 0:00:01
#      -------------------------------------- 81.9/81.9 kB 218.3 kB/s eta 0:00:00
# Collecting azure-core>=1.31.0 (from azure-identity)
#   Obtaining dependency information for azure-core>=1.31.0 from https://files.pythonhosted.org/packages/84/9e/5c87b49f65bb16571599bc789857d0ded2f53014d3392bc88a5d1f3ad779/azure_core-1.34.0-py3-none-any.whl.metadata
#   Downloading azure_core-1.34.0-py3-none-any.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB 1.1 MB/s eta 0:00:00
# Collecting cryptography>=2.5 (from azure-identity)
#   Obtaining dependency information for cryptography>=2.5 from https://files.pythonhosted.org/packages/c7/75/063bc9ddc3d1c73e959054f1fc091b79572e716ef74d6caaa56e945b4af9/cryptography-45.0.3-cp311-abi3-win_amd64.whl.metadata
#   Downloading cryptography-45.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting msal>=1.30.0 (from azure-identity)
#   Obtaining dependency information for msal>=1.30.0 from https://files.pythonhosted.org/packages/04/bf/81516b9aac7fd867709984d08eb4db1d2e3fe1df795c8e442cde9b568962/msal-1.32.3-py3-none-any.whl.metadata
#   Using cached msal-1.32.3-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity)
#   Obtaining dependency information for msal-extensions>=1.2.0 from https://files.pythonhosted.org/packages/5e/75/bd9b7bb966668920f06b200e84454c8f3566b102183bc55c5473d96cb2b9/msal_extensions-1.3.1-py3-none-any.whl.metadata
#   Using cached msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in .\.venv\lib\site-packages (from azure-identity) (4.13.2)
# Collecting requests>=2.21.0 (from azure-core>=1.31.0->azure-identity)
#   Obtaining dependency information for requests>=2.21.0 from https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl.metadata
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six>=1.11.0 in .\.venv\lib\site-packages (from azure-core>=1.31.0->azure-identity) (1.17.0)
# Collecting cffi>=1.14 (from cryptography>=2.5->azure-identity)
#   Obtaining dependency information for cffi>=1.14 from https://files.pythonhosted.org/packages/50/b9/db34c4755a7bd1cb2d1603ac3863f22bcecbd1ba29e5ee841a4bc510b294/cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata
#   Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata (1.6 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0 (from msal>=1.30.0->azure-identity)
#   Obtaining dependency information for PyJWT[crypto]<3,>=1.0.0 from https://files.pythonhosted.org/packages/61/ad/689f02752eeec26aed679477e80e632ef1b682313be70793d798c1d5fc8f/PyJWT-2.10.1-py3-none-any.whl.metadata
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting pycparser (from cffi>=1.14->cryptography>=2.5->azure-identity)
#   Obtaining dependency information for pycparser from https://files.pythonhosted.org/packages/13/a3/a812df4e2dd5696d1f351d58b8fe16a405b234ad2886a0dab9183fb78109/pycparser-2.22-py3-none-any.whl.metadata
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting charset-normalizer<4,>=2 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/6c/4f/c02d5c493967af3eda9c771ad4d2bbc8df6f99ddbeb37ceea6e8716a32bc/charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl.metadata
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.4.0)
# Collecting certifi>=2017.4.17 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/4a/7e/3db2bd1b1f9e95f7cddca6d6e75e2f2bd9f51b1246e546d88addca0106bd/certifi-2025.4.26-py3-none-any.whl.metadata
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Downloading azure_identity-1.23.0-py3-none-any.whl (186 kB)
#    ---------------------------------------- 0.0/186.1 kB ? eta -:--:--
#    -------- ------------------------------ 41.0/186.1 kB 991.0 kB/s eta 0:00:01
#    ------------------- -------------------- 92.2/186.1 kB 1.3 MB/s eta 0:00:01
#    ------------------- -------------------- 92.2/186.1 kB 1.3 MB/s eta 0:00:01
#    ------------------------- ------------ 122.9/186.1 kB 654.9 kB/s eta 0:00:01
#    -------------------------------------- 186.1/186.1 kB 803.0 kB/s eta 0:00:00
# Downloading azure_core-1.34.0-py3-none-any.whl (207 kB)
#    ---------------------------------------- 0.0/207.4 kB ? eta -:--:--
#    --------------------------------- ------ 174.1/207.4 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 207.4/207.4 kB 3.2 MB/s eta 0:00:00
# Downloading cryptography-45.0.3-cp311-abi3-win_amd64.whl (3.4 MB)
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/3.4 MB 5.6 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.4/3.4 MB 5.0 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.4/3.4 MB 5.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.5/3.4 MB 2.7 MB/s eta 0:00:02
#    --------- ------------------------------ 0.8/3.4 MB 3.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.9/3.4 MB 3.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.9/3.4 MB 3.9 MB/s eta 0:00:01
#    -------------- ------------------------- 1.2/3.4 MB 3.3 MB/s eta 0:00:01
#    -------------------- ------------------- 1.8/3.4 MB 4.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.0/3.4 MB 4.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.0/3.4 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 2.8/3.4 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.4 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.4/3.4 MB 5.6 MB/s eta 0:00:00
# Using cached msal-1.32.3-py3-none-any.whl (115 kB)
# Using cached msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl (105 kB)
#    ---------------------------------------- 0.0/105.8 kB ? eta -:--:--
#    ---------------------------------------- 105.8/105.8 kB ? eta 0:00:00
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Installing collected packages: PyJWT, pycparser, idna, charset-normalizer, certifi, requests, cffi, cryptography, azure-core, msal, msal-extensions, azure-identity
# Successfully installed PyJWT-2.10.1 azure-core-1.34.0 azure-identity-1.23.0 certifi-2025.4.26 cffi-1.17.1 charset-normalizer-3.4.2 cryptography-45.0.3 idna-3.10 msal-1.32.3 msal-extensions-1.3.1 pycparser-2.22 requests-2.32.3
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting python-dotenv
#   Obtaining dependency information for python-dotenv from https://files.pythonhosted.org/packages/1e/18/98a99ad95133c6a6e2005fe89faedf294a748bd5dc803008059409ac9b1e/python_dotenv-1.1.0-py3-none-any.whl.metadata
#   Using cached python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Using cached python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.0
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nest_asyncio in .\.venv\lib\site-packages (1.6.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pytz
#   Obtaining dependency information for pytz from https://files.pythonhosted.org/packages/81/c4/34e93fe5f5429d7570ec1fa436f1986fb1f00c3e0f43a589fe2bbcd22c3f/pytz-2025.2-py2.py3-none-any.whl.metadata
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.2 kB ? eta -:--:--
#     --------------------------------------- 10.2/509.2 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/509.2 kB 330.3 kB/s eta 0:00:02
#    --- ----------------------------------- 41.0/509.2 kB 330.3 kB/s eta 0:00:02
#    ---- ---------------------------------- 61.4/509.2 kB 365.7 kB/s eta 0:00:02
#    ------- ------------------------------- 92.2/509.2 kB 438.1 kB/s eta 0:00:01
#    ---------- --------------------------- 143.4/509.2 kB 532.5 kB/s eta 0:00:01
#    ------------ ------------------------- 174.1/509.2 kB 583.1 kB/s eta 0:00:01
#    ---------------- --------------------- 225.3/509.2 kB 626.9 kB/s eta 0:00:01
#    ------------------------- ------------ 337.9/509.2 kB 840.2 kB/s eta 0:00:01
#    ------------------------------- ------ 419.8/509.2 kB 937.3 kB/s eta 0:00:01
#    ----------------------------------- -- 481.3/509.2 kB 973.2 kB/s eta 0:00:01
#    -------------------------------------- 509.2/509.2 kB 998.0 kB/s eta 0:00:00
# Installing collected packages: pytz
# Successfully installed pytz-2025.2
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Authenticate and Initialize Graph

# %%
# Get the keys from .env file
import os
from dotenv import load_dotenv
load_dotenv()

# Get the client ID and secret from environment variables
tenant_id = os.getenv("AZURE_TENANT_ID")
client_id = os.getenv("AZURE_CLIENT_ID")
client_secret = os.getenv("AZURE_CLIENT_SECRET")
current_user_id = os.getenv("USER_ID")

# Display the values (redacted for security)
print(f"Client ID: {client_id[:5]}... (redacted)" if client_id else "Client ID: Not found")
print(f"Client Secret: {'*' * 8}" if client_secret else "Client Secret: Not found")
print(f"Tenant ID: {tenant_id[:5]}... (redacted)" if tenant_id else "Tenant ID: Not found")

# %% [markdown]
# ### Initialize Graph Client

# %%
# Configure Graph client for app-only authentication 
from azure.identity import ClientSecretCredential
from msgraph import GraphServiceClient

# Verify that environment variables are set before proceeding
if not all([client_id, client_secret, tenant_id]):
    raise ValueError("One or more required environment variables are not set. Please check your .env file.")

# Print the type of the env variables to ensure they are strings
print(f"Tenant ID: {tenant_id} (Type: {type(tenant_id)})")
print(f"Client ID: {client_id} (Type: {type(client_id)})")
print(f"Client Secret: {client_secret} (Type: {type(client_secret)})")

credential = ClientSecretCredential(
    tenant_id=tenant_id,
    client_id=client_id,
    client_secret=client_secret
)

# Create a Graph client using the credential object
graph_client = GraphServiceClient(credential)
print("Graph client initialized successfully")

# %% [markdown]
# ### Get Token

# %%
# Function to get an access token using ClientSecretCredential
def get_token():
    try:
        # Use the default scope for Microsoft Graph
        graph_scope = "https://graph.microsoft.com/.default"
        
        # Get the token synchronously
        token = credential.get_token(graph_scope)
        return token.token
    except Exception as e:
        print(f"Error obtaining token: {e}")
        raise

# %% [markdown]
# ### Display Token

# %%
# Display the access token
def display_access_token():
    try:
        # Get the access token
        token = get_token()
        
        # Display a part of the access token for security
        if token:
            token_length = len(token)
            print(f"Access Token: {token[:25]}...{token[-5:]}")
            print(f"Token length: {token_length} characters")
            print("\nWARNING: This token contains sensitive credentials.")
            print("Do not share or commit this token to version control.")
        else:
            print("Failed to retrieve token.")
            
        return token
    except Exception as e:
        print(f"Error retrieving token: {e}")
        return None

# %%
# Get and display the token
# token = display_access_token()

# %%
# Display the raw token (for debugging purposes)
def display_raw_token():
    try:
        token = get_token()
        print(token)
        print(f"\nRaw token displayed. Length: {len(token)} characters")
        return token
    except Exception as e:
        print(f"Error displaying raw token: {e}")
        return None

# %%
# Uncomment the line below to see the full raw token (use with caution)
# raw_token = display_raw_token()

# %% [markdown]
# ### List Users

# %% [markdown]
# Get users v1

# %%
import asyncio

async def get_users_async():
    try:
        # Get the list of users with the async approach
        users_response = await graph_client.users.get()
        
        # Print the user details
        print(f"Retrieved {len(users_response.value)} users")
        for user in users_response.value:
            # Use proper property access for user objects
            display_name = user.display_name if hasattr(user, 'display_name') else 'No display name'
            email = user.mail if hasattr(user, 'mail') and user.mail else user.user_principal_name
            print(f"User ID: {user.id}, Name: {display_name}, Email: {email}")
        
        return users_response.value
    except Exception as e:
        print(f"Error retrieving users: {e}")
        import traceback
        traceback.print_exc()
        return None

# %% [markdown]
# Get users v2

# %%
from msgraph.generated.users.users_request_builder import UsersRequestBuilder

async def get_users_async_v2():
    try:
        # Set the top limit for the number of users to retrieve
        topLimit = 50

        # Build query parameters for Users Request Builder
        query_params = UsersRequestBuilder.UsersRequestBuilderGetQueryParameters(
            select = ['displayName', 'id', 'mail'],
            top = topLimit,
            orderby = ['displayName desc']
        )

        # create a request_config object
        request_config = UsersRequestBuilder.UsersRequestBuilderGetRequestConfiguration(
            query_parameters=query_params
        )

        # Get the list of users with the async approach
        users_response = await graph_client.users.get(request_configuration=request_config)
        
        # Print the user details (limited to 10 for display purposes)
        count = 0
        for user in users_response.value:
            print(f"User ID: {user.id}, Display Name: {user.display_name}, Email: {user.mail or user.user_principal_name}")
            count += 1
            if count >= topLimit:
                break
        
        return users_response.value
    except Exception as e:
        print(f"Error retrieving users: {e}")
        return None

# %%
# Import required libraries
import asyncio
import nest_asyncio

# Apply nest_asyncio to allow running asyncio in Jupyter notebook
nest_asyncio.apply()

# Display Users using async execution
try:
    # Use asyncio directly now that we've patched it with nest_asyncio
    loop = asyncio.get_event_loop()

    users = loop.run_until_complete(get_users_async())
    # users = loop.run_until_complete(get_users_async_v2())

    print(f"\nTotal users retrieved: {len(users) if users else 0}")
except Exception as e:
    print(f"Error executing async function: {e}")
    
    import traceback
    traceback.print_exc()

# %% [markdown]
# Tabulate Data

# %%
from tabulate import tabulate

def tabulate_calendar_events(events):
    table_data = []
    for i, event in enumerate(events, 1):
        subject = event.subject or "(No subject)"
        organizer = event.organizer.email_address.name if event.organizer and hasattr(event.organizer, 'email_address') else "Unknown"

        start_time_dt_pst = convert_to_pst(event.start.date_time)
        start_time = start_time_dt_pst.strftime("%Y-%m-%d %H:%M:%S %Z")

        end_time_dt_pst = convert_to_pst(event.end.date_time)
        end_time = end_time_dt_pst.strftime("%Y-%m-%d %H:%M:%S %Z")

        location = event.location.display_name if event.location else "No location"
        is_all_day = "Yes" if event.is_all_day else "No"
        importance = event.importance.capitalize() if event.importance and event.importance != 'normal' else "Normal"

        attendees = ", ".join(
            f"{a.email_address.name} ({a.email_address.address})"
            for a in event.attendees
        ) if hasattr(event, 'attendees') and event.attendees else "None"

        table_data.append([
            i, subject, organizer, start_time, end_time,
            location, is_all_day, importance, attendees
        ])

    headers = ["#", "Subject", "Organizer", "Start Time", "End Time", "Location", "All Day", "Importance", "Attendees"]
    print(tabulate(table_data, headers=headers, tablefmt="grid"))

# %% [markdown]
# ### Get Calendar View
#
# Retrieve calendar events within a specific time range

# %%
import datetime
import pytz
from msgraph.generated.users.item.calendar.calendar_view.calendar_view_request_builder import CalendarViewRequestBuilder

def convert_to_pst(date_time_str):
    utc_timezone = pytz.timezone("UTC")
    dt = datetime.datetime.fromisoformat(date_time_str)
    dt_utc = utc_timezone.localize(dt)
    pst_timezone = pytz.timezone('America/Los_Angeles')
    dt_pst = dt_utc.astimezone(pst_timezone)
    return dt_pst

async def get_calendar_view(user_id=None):
    try:
        # Create datetime objects for the date range
        now = datetime.datetime.now(pytz.timezone("America/Los_Angeles"))
        start_date = now
        end_date = now.replace(hour=23, minute=59, second=59, microsecond=999999)
        
        # Create query parameters for the calendar view request
        query_parameters = CalendarViewRequestBuilder.CalendarViewRequestBuilderGetQueryParameters(
            start_date_time=start_date,
            end_date_time=end_date,
            top=10,
            select=['subject', 'organizer', 'start', 'end', 'isAllDay', 'location', 'bodyPreview', 'importance', 'attendees'],
            orderby=['start/dateTime asc']
        )

        # Check if we're getting calendar for a specific user or the current user
        print(f"Fetching calendar events for user {user_id} from {start_date} to {end_date}")
        
        # For specific user
        # Step 1: Create request parameters
        request_config = CalendarViewRequestBuilder.CalendarViewRequestBuilderGetRequestConfiguration(
            query_parameters=query_parameters
        )

        # Step 3: Make the call
        calendar_view = await graph_client.users.by_user_id(user_id).calendar.calendar_view.get(request_configuration=request_config)
                
        # Process and display the events
        if hasattr(calendar_view, 'value') and calendar_view.value:
            print(f"Retrieved {len(calendar_view.value)} calendar events.")
            tabulate_calendar_events(calendar_view.value)
        else:
            print("No events found in the specified time range.")
        return calendar_view.value if hasattr(calendar_view, 'value') else []
    except Exception as e:
        print(f"Error retrieving calendar view: {e}")
        import traceback
        traceback.print_exc()
        return None

# %% [markdown]
# Display Calendar Events

# %%
# Import required libraries
import asyncio
import nest_asyncio

# Apply nest_asyncio to allow running asyncio in Jupyter notebook
nest_asyncio.apply()

try:
    # Use asyncio directly now that we've patched it with nest_asyncio
    loop = asyncio.get_event_loop()

    # Using the nest_asyncio approach we established earlier
    user_calendar_events = loop.run_until_complete(get_calendar_view(user_id=current_user_id))
    
    # Summary of results
    if user_calendar_events:
        print(f"\nSummary: Retrieved {len(user_calendar_events)} calendar events for user {current_user_id}.")
    else:
        print(f"No calendar events were retrieved for user {current_user_id} or an error occurred.")
except Exception as e:
    print(f"Error executing calendar view function for specific user: {e}")
    import traceback
    traceback.print_exc()

# %%
# Create a function to take the current date and time and create a start and end date where the start date is now and the end date is today at 12 midinght
def get_today_start_end():
    # Get the current date and time
    now = datetime.datetime.now(pytz.timezone("America/Los_Angeles"))
    
    # Create start and end dates
    start_date = now
    end_date = now.replace(hour=23, minute=59, second=59, microsecond=999999)
    
    return start_date, end_date

# Test the function
start_date, end_date = get_today_start_end()
print(f"Start date: {start_date}")
print(f"Dst: {start_date.dst()}")  
print(f"UtcOffset: {start_date.utcoffset()}")  
print(f"End date: {end_date}")
print(f"Dst: {end_date.dst()}")  
print(f"UtcOffset: {end_date.utcoffset()}")

# %% [markdown]
# Clean Create Event function response

# %%
import re
from bs4 import BeautifulSoup

def clean_body_response(html_content: str) -> dict:
    """
    Extracts important parts from the HTML email body content.
    Returns a dictionary with the main description, meeting ID, and passcode.
    """
    soup = BeautifulSoup(html_content, "html.parser")
    text = soup.get_text(separator="\n")

    # Normalize excessive newlines and trim
    text = re.sub(r'\n\s*\n+', '\n', text).strip()

    details = {
        "description": "",
        "meeting_id": "",
        "passcode": ""
    }

    # Extract description before the Microsoft Teams section
    split_text = text.split("Microsoft Teams")
    details["description"] = split_text[0].strip() if split_text else ""

    # Extract meeting ID
    match = re.search(r"Meeting ID:\s*(\d[\d\s]*)", text)
    if match:
        details["meeting_id"] = match.group(1).strip()

    # Extract passcode
    match = re.search(r"Passcode:\s*(\S+)", text)
    if match:
        details["passcode"] = match.group(1).strip()

    return details

# %% [markdown]
# Validate Create calendar inputs

# %%
from datetime import datetime
from msgraph.generated.models.recurrence_pattern_type import RecurrencePatternType

def validate_event_input(
    subject: str,
    start_datetime: datetime,
    end_datetime: datetime,
    attendees: list = None,
    recurrence: dict = None
):
    if not subject or not isinstance(subject, str):
        raise ValueError("Subject must be a non-empty string.")

    if not isinstance(start_datetime, datetime) or not isinstance(end_datetime, datetime):
        raise ValueError("Start and end datetime must be datetime objects.")

    if start_datetime >= end_datetime:
        raise ValueError("Start datetime must be before end datetime.")

    if attendees:
        for email in attendees:
            if not isinstance(email, str) or '@' not in email:
                raise ValueError(f"Invalid email format: {email}")

    if recurrence:
        valid_types = {e.value for e in RecurrencePatternType}
        recurrence_type = recurrence.get('type', 'daily')
        if recurrence_type not in valid_types:
            raise ValueError(f"Invalid recurrence type: {recurrence_type}. Must be one of {valid_types}")

        range_type = recurrence.get('range_type', 'noEnd')
        if range_type == 'endDate' and 'end_date' not in recurrence:
            raise ValueError("Missing 'end_date' for recurrence with range_type 'endDate'.")
        if range_type == 'numbered' and 'occurrences' not in recurrence:
            raise ValueError("Missing 'occurrences' for recurrence with range_type 'numbered'.")

# %% [markdown]
# Create Event Function

# %%
from datetime import datetime
import pytz
from msgraph.generated.models.event import Event
from msgraph.generated.models.item_body import ItemBody
from msgraph.generated.models.body_type import BodyType
from msgraph.generated.models.date_time_time_zone import DateTimeTimeZone
from msgraph.generated.models.attendee import Attendee
from msgraph.generated.models.email_address import EmailAddress
from msgraph.generated.models.location import Location
from msgraph.generated.models.patterned_recurrence import PatternedRecurrence
from msgraph.generated.models.recurrence_pattern import RecurrencePattern
from msgraph.generated.models.recurrence_range import RecurrenceRange
from msgraph.generated.models.recurrence_pattern_type import RecurrencePatternType
from msgraph.generated.models.importance import Importance
from msgraph.generated.models.response_status import ResponseStatus

async def create_calendar_event(
    user_id: str,
    subject: str,
    content: str,
    start_datetime: datetime,
    end_datetime: datetime,
    timezone: str = 'Asia/Manila',
    is_online_meeting: bool = False,
    attendees: list = None,
    location: str = None,
    is_all_day: bool = False,
    importance: Importance = Importance.Normal,
    recurrence: dict = None
):
    """
    Create a new calendar event for the specified user (application-level).
    """
    try:
        if not start_datetime.tzinfo:
            start_datetime = pytz.timezone(timezone).localize(start_datetime)
        if not end_datetime.tzinfo:
            end_datetime = pytz.timezone(timezone).localize(end_datetime)

        event = Event()
        event.subject = subject

        event.body = ItemBody()
        event.body.content_type = BodyType.Html
        event.body.content = content

        event.start = DateTimeTimeZone()
        event.start.date_time = start_datetime.isoformat()
        event.start.time_zone = "Pacific Standard Time"

        event.end = DateTimeTimeZone()
        event.end.date_time = end_datetime.isoformat()
        event.end.time_zone = "Pacific Standard Time"

        event.is_all_day = is_all_day
        event.importance = importance

        if location:
            event.location = Location()
            event.location.display_name = location

        if attendees:
            event.attendees = []
            for email in attendees:
                attendee = Attendee()
                attendee.email_address = EmailAddress(address=email)
                attendee.status = ResponseStatus(response="none")
                event.attendees.append(attendee)

        event.is_online_meeting = is_online_meeting
        if is_online_meeting:
            event.online_meeting_provider = "teamsForBusiness"

        if recurrence:
            pattern = RecurrencePattern()
            pattern.type_ = RecurrencePatternType(recurrence.get('type', 'daily'))
            pattern.interval = recurrence.get('interval', 1)
            if pattern.type_ == RecurrencePatternType.Weekly:
                pattern.days_of_week = recurrence.get('days_of_week', [])

            range_ = RecurrenceRange()
            range_.type_ = recurrence.get('range_type', 'noEnd')
            range_.start_date = start_datetime.date()

            if range_.type_ == 'endDate':
                range_.end_date = recurrence.get('end_date')
            elif range_.type_ == 'numbered':
                range_.number_of_occurrences = recurrence.get('occurrences', 5)

            event.recurrence = PatternedRecurrence(pattern=pattern, range=range_)

        created_event = await graph_client.users.by_user_id(user_id).events.post(event)
        print(f"Event created successfully: {created_event.id}")
        print(f"Web link: {created_event.web_link}")
        print(f"Subject: {created_event.subject}")
        event_summary = clean_body_response(created_event.body.content if created_event.body else "") 
        print(f"Description: {event_summary['description']}")
        print(f"Meeting ID: {event_summary['meeting_id']}")
        print(f"Passcode: {event_summary['passcode']}")
        print(f"Start: {created_event.start.date_time} ({created_event.start.time_zone})")
        print(f"End: {created_event.end.date_time} ({created_event.end.time_zone})")
        print(f"Location: {created_event.location.display_name if created_event.location else 'None'}")
        print(f"All Day: {'Yes' if created_event.is_all_day else 'No'}")
        print(f"Importance: {created_event.importance}")
        print("Attendees:")

        if created_event.attendees:
            for attendee in created_event.attendees:
                name = attendee.email_address.name if attendee.email_address.name else attendee.email_address.address
                email = attendee.email_address.address
                print(f"  - {name} ({email})")
        else:
            print("  None")

        if created_event.recurrence:
            print("Recurrence:")
            print(f"  Pattern Type: {created_event.recurrence.pattern.type}")
            print(f"  Interval: {created_event.recurrence.pattern.interval}")
            if created_event.recurrence.pattern.days_of_week:
                print(f"  Days of Week: {', '.join(created_event.recurrence.pattern.days_of_week)}")
            print(f"  Range Type: {created_event.recurrence.range.type}")
            print(f"  Start Date: {created_event.recurrence.range.start_date}")
            if created_event.recurrence.range.end_date:
                print(f"  End Date: {created_event.recurrence.range.end_date}")
            if created_event.recurrence.range.number_of_occurrences:
                print(f"  Occurrences: {created_event.recurrence.range.number_of_occurrences}")

        return created_event

    except Exception as e:
        print(f"Error creating event: {e}")
        import traceback
        traceback.print_exc()
        return None

# %% [markdown]
# Create the actual event

# %%
import asyncio
import nest_asyncio
from datetime import datetime, timedelta

# Apply nest_asyncio to enable asyncio in Jupyter
nest_asyncio.apply()

# Create a test event
tz = pytz.timezone("Asia/Manila")
now = datetime.now(tz)
start_time = tz.localize(datetime(now.year, now.month, now.day, 16, 0)) #4pm
end_time = start_time + timedelta(hours=1)

#This is a sample payload for creating 1 instance event
event_data = {
    "subject": "Test create event function june 2",
    "content": "<p>This is a test meeting for creating event</p>",
    "start_datetime": start_time,
    "end_datetime": end_time,
    "is_online_meeting": True,
    "attendees": [""],
    "location": "Jairosoft",
    "importance": "Normal",
    "recurrence": None,
    "user_id": current_user_id  # replace with actual user ID
}

event_data_recurring ={
    "subject": "Daily Standup Meeting",
    "content": "<p>Daily team standup</p>",
    "start_datetime": start_time,
    "end_datetime": end_time,
    "is_online_meeting": True,
    "attendees": [""],
    "location": "Conference Room",
    "importance": "Normal",
    "recurrence": {
        "type": "daily",
        "interval": 1,
        "range_type": "endDate",
        "end_date": datetime(2025, 6, 4).date()
    },
    "user_id": current_user_id  # Replace with actual user ID
}

validate_event_input(
    subject=event_data["subject"],
    start_datetime=event_data["start_datetime"],
    end_datetime=event_data["end_datetime"],
    attendees=event_data.get("attendees"),
    recurrence=event_data.get("recurrence")
)

#event = await create_calendar_event(**event_data) #Uncomment this line to create a 1 instance event

event = await create_calendar_event(**event_data_recurring) #Uncomment this line to create a recurring event
